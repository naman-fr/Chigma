# %% [markdown]
# # Chigma - FD-YOLO11 Training Exploration
#
# Interactive training experiments using Ultralytics and custom training loops.

# %%
from src.detection.train import Trainer

trainer = Trainer('../configs/training.yaml')
trainer.setup_mlflow()

# Note: Run this cell only if data is available in data/processed
# metrics = trainer.train_with_ultralytics('../configs/dataset.yaml')
# print(metrics)
