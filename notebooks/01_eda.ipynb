# %% [markdown]
# # Chigma - Exploratory Data Analysis
#
# This notebook covers initial data exploration for the NEU-DET and GC10-DET steel defect datasets.

# %%
import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import yaml

# Load dataset config
with open('../configs/dataset.yaml') as f:
    config = yaml.safe_load(f)
print(f"Loaded classes: {config['names']}")
